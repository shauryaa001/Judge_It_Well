# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
#we use plt.show() if we aren't using jupyter notebook

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
import numpy as np
x = np.arange(0,100)
import matplotlib.pyplot as plt
y = x*2
z = x**2
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('title')

# plt.show()
ob=plt.figure()
new=ob.add_axes([0,0,1,1])
print(ob)
# Out:
# Figure(640x480)

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([0,0,1,1])
y=np.array([0.2,0.5,.2,.2])
fig=plt.figure();
fig.add_axes(x)
fig.add_axes(y)
print(fig)
# Out:
# Figure(640x480)

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2
import matplotlib.pyplot as plt
x1=np.array([0,0,1,1])
y1=np.array([0.2,0.5,.2,.2])
fig=plt.figure();

ax1=fig.add_axes(x1)
ax2=fig.add_axes(y1)
ax1.plot(x,y,color='red')
plt.plot(x,y,color='pink')

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
import numpy as np
import matplotlib.pyplot as plt
x1=np.array([0,0,1,1])
y1=np.array([0.2,0.5,.4,.4])
fig=plt.figure();
fig.add_axes(x1)
fig.add_axes(y1)
print(fig)
# Out:
# Figure(640x480)

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2
import numpy as np
import matplotlib.pyplot as plt
x1=np.array([0,0,1,1])
y1=np.array([0.2,0.5,.4,.4])
fig=plt.figure();
ax1=fig.add_axes(x1)
ax2=fig.add_axes(y1)
ax1.plot(x,z)
x3=np.arange(20,40)
y3=x3*2
plt.plot(x3,y3)

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
plt.subplot(1, 2, 2)
x = np.arange(0,100)
y = x*2
z = x**2
# Out:
# <Axes: >

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = x*2
z = x**2
plt.subplot(1, 2, 1)
plt.plot(x,y,linestyle='dashed',color='blue')
plt.subplot(1, 2, 2)
plt.plot(x,z,color='red')

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = x*2
z = x**2
plt.figure(figsize=(6,2))
plt.subplot(1, 2, 1)
plt.plot(x,y,linestyle='dashed',color='blue')
plt.subplot(1, 2, 2)
plt.plot(x,z,color='red')

# %% [markdown]
# # #**Plots**
#
# Plot the following plots using matplotlib, you many generate your own data or get it from the internet:
#
# 1. Histogram
# 2. Scatter Plot
# 3. Boxplot
# 4. Pie charts
#
# (Bonus - Read up on the use-case of histograms in EDA and ML in general, they are VERY useful! Also, look up **Violin plots** if you have extra time)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
hours_studied = np.array([2, 4, 5, 7, 9])  # X-axis data
exam_score = np.array([55, 72, 88, 91, 95]) # Y-axis data

plt.scatter(hours_studied,exam_score)

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.array([10, 15, 17, 20, 21, 25, 26, 27, 28, 30, 45])
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bf440972ea0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bf442f87cb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bf44057c800>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bf43be0f2c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bf43be0ea20>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import numpy as np
sizes = [50000, 30000, 20000]
labels = ['green', 'red', 'blue']
colors = ['green', 'red', 'blue']
plt.pie(sizes,labels=labels,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7bf437732570>,
# ...
#  [Text(-4.8082529002048655e-08, 1.099999999999999, 'green'),
#   Text(-0.6465639946425109, -0.8899185360649138, 'red'),
#   Text(0.8899186414035474, -0.6465638496563697, 'blue')])
